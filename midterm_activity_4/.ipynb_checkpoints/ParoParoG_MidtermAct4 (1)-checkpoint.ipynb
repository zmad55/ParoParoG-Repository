# %% [raw]
# Cabuenas, Michael Luke
# Diño, Karylle Marie
# Domantay, Nico Bernard
# Ferrer, Miguel Patrick
# Madriaga, Jeremy
# Mendoza, Bryan Benchmark
# Napeek, Kaiser Moen

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# # Pre-Processing

# %%
uncleaned_data = pd.read_csv('Outdoor Activities.csv')

# %%
# Removing unwanted columns
uncleaned_data = uncleaned_data.drop(["Timestamp", "Do you agree to become a respondent in this study?"], axis=1)

# %%
uncleaned_data.rename(columns = {
    
    "Approximate average income / allowance per month (₱)":"Average Income/Allowance", "Current Region (Philippines)":"Region", 
    "Choose whether you participate in any outdoor activities alone or in a group.":"Participation Type", 
    "How many people in the group generally participate in outdoor activities? (Yourself Included)":"Number of Members",
    "Individual Budget. This includes travel, eating, and other areas (₱)":"Individual Budget",
    
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Swimming]":"Swimming",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Scuba Diving]":"Scuba Diving",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Surfing]":"Surfing",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Wakeboarding]":"Wakeboarding",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Boating]":"Boating",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Biking]":"Biking",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Hiking]":"Hiking",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Basketball]":"Basketball",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Volleyball]":"Volleyball",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Golfing]":"Golfing",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Sky Diving]":"Sky Diving",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Bungee Jumping]":"Bungee Jumping",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Tennis]":"Tennis",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Fishing]":"Fishing",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Camping]":"Camping",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Badminton]":"Badminton",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Sightseeing]":"Sightseeing",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Picnic]":"Picnic",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [FoodTrip]":"FoodTrip",
    "Based on the season, choose outdoor activities that you have enjoyed doing alone or with friends. (Select all that apply) [Wildlife Viewing]":"Wildlife Viewing",
    
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Swimming]":"Swimming Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Scuba Diving]":"Scuba Diving Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Surfing]":"Surfing Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Wakeboarding]":"Wakeboarding Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Boating]":"Boating Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Biking]":"Biking Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Hiking]":"Hiking Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Basketball]":"Basketball Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Volleyball]":"Volleyball Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Golfing]":"Golfing Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Sky Diving]":"Sky Diving Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Bungee Jumping]":"Bungee Jumping Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Tennis]":"Tennis Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Fishing]":"Fishing Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Camping]":"Camping Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Badminton]":"Badminton Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Sightseeing]":"Sightseeing Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Picnic]":"Picnic Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [FoodTrip]":"FoodTrip Rating",
    "Rate the outdoor activity from 1 to 5. (1 being the lowest; 5 being the highest) [Wildlife Viewing]":"Wildlife Viewing Rating",
    
    "Do you have anything more you like to do during the DRY SEASON in addition to the outdoor activities on the list? If Yes, please input exactly one (1) activity.":"Dry Season Addition",
    "Do you have more you like to do during the RAINY SEASON in addition to the outdoor activities on the list? If Yes, please input exactly one (1) activity.":"Rainy Season Addition",
    "Thinking about the outdoor activities that you haven't tried; what keeps you from doing these activities?":"Preventing Forces"
    
}, inplace = True)

uncleaned_data.columns = uncleaned_data.columns.str.replace(r'\s+', '_', regex=True)

# %%
# Check column names
print(uncleaned_data.columns)
# Out:
# Index(['Age_Group', 'Gender', 'Marital_Status', 'Employment_Status',
#        'Average_Income/Allowance', 'Region', 'Participation_Type',
#        'Number_of_Members', 'Individual_Budget', 'Swimming', 'Scuba_Diving',
#        'Surfing', 'Wakeboarding', 'Boating', 'Biking', 'Hiking', 'Basketball',
#        'Volleyball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis',
#        'Fishing', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip',
#        'Wildlife_Viewing', 'Swimming_Rating', 'Scuba_Diving_Rating',
#        'Surfing_Rating', 'Wakeboarding_Rating', 'Boating_Rating',
#        'Biking_Rating', 'Hiking_Rating', 'Basketball_Rating',
#        'Volleyball_Rating', 'Golfing_Rating', 'Sky_Diving_Rating',
#        'Bungee_Jumping_Rating', 'Tennis_Rating', 'Fishing_Rating',
#        'Camping_Rating', 'Badminton_Rating', 'Sightseeing_Rating',
#        'Picnic_Rating', 'FoodTrip_Rating', 'Wildlife_Viewing_Rating',
#        'Dry_Season_Addition', 'Rainy_Season_Addition', 'Preventing_Forces'],
#       dtype='object')

# %%
# Notice how the symbol '-' in region is not actually a '-', but rather a '–'
# Replace all instances of '–' with regular '-'
uncleaned_data["Region"] = uncleaned_data["Region"].str.replace('–', '-')

# %%
data = uncleaned_data
data.head()
# Out:
#        Age_Group  Gender Marital_Status Employment_Status  \
# 0  18 - 25 years    Male         Single           Student
# 1  18 - 25 years    Male         Single           Student
# 2  18 - 25 years    Male         Single           Student
# 3  18 - 25 years  Female         Single           Student
# 4  18 - 25 years  Female         Single           Student
#
#   Average_Income/Allowance                                  Region  \
# 0                   < 4999  CAR - Cordillera Administrative Region
# 1   Prefer not to disclose              Region III - Central Luzon
# 2            10000 - 19999  CAR - Cordillera Administrative Region
# 3            10000 - 19999  CAR - Cordillera Administrative Region
# 4   Prefer not to disclose                Region I - Ilocos Region
#
#                 Participation_Type Number_of_Members Individual_Budget  \
# 0  With Both Friends and Relatives            5 - 10       1000 - 1999
# 1                             Solo               < 5             < 999
# 2  With Both Friends and Relatives            5 - 10       1000 - 1999
# 3                     With Friends               < 5             < 999
# 4  With Both Friends and Relatives            5 - 10             < 999
#
#                   Swimming  ... Fishing_Rating Camping_Rating  \
# 0               Dry Season  ...  Haven't Tried  Haven't Tried
# 1  Dry Season;Rainy Season  ...              1              2
# 2               Dry Season  ...  Haven't Tried              4
# 3  Dry Season;Rainy Season  ...              3              5
# 4               Dry Season  ...  Haven't Tried              5
#
#   Badminton_Rating Sightseeing_Rating Picnic_Rating FoodTrip_Rating  \
# 0    Haven't Tried                  3             4               5
# 1                1                  3             3               2
# 2                4                  5             5               5
# 3                4                  5             5               5
# 4                4                  3             5               5
#
#   Wildlife_Viewing_Rating Dry_Season_Addition Rainy_Season_Addition  \
# 0           Haven't Tried                None                  None
# 1           Haven't Tried                None                  None
# 2                       5                None                  None
# 3                       5                None                  None
# 4           Haven't Tried                None                  None
#
#                                    Preventing_Forces
# 0  The activities are out of my budget;I don't ha...
# 1  I simply don't like the activities;The activit...
# 2  I simply don't like the activities;The activit...
# 3                 I simply don't like the activities
# 4  The activities are out of my budget;Not enough...
#
# [5 rows x 52 columns]

# %%
# Group each columns - List

personal_data_colnames = ['Age_Group', 'Gender', 'Marital_Status', 'Employment_Status', 'Average Income/Allowance', 'Region']

pre_assessment_colnames = ['Participation_Type', 'Number_of_Members', 'Individual_Budget']

outdoor_activities_colnames = ['Swimming', 'Scuba_Diving', 'Surfing', 'Wakeboarding', 'Boating', 'Biking', 'Hiking', 'Basketball',
                           'Volleyball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing', 'Camping', 'Badminton', 
                           'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing']
                    
rating_colnames = ['Swimming_Rating', 'Scuba_Diving_Rating', 'Surfing_Rating', 'Wakeboarding_Rating', 'Boating_Rating',
                  'Biking_Rating', 'Hiking_Rating', 'Basketball_Rating', 'Volleyball_Rating', 'Golfing_Rating', 'Sky_Diving_Rating',
                  'Bungee_Jumping_Rating', 'Tennis_Rating', 'Fishing_Rating', 'Camping_Rating', 'Badminton_Rating', 
                  'Sightseeing_Rating', 'Picnic_Rating', 'FoodTrip_Rating', 'Wildlife_Viewing_Rating']

# %% [markdown]
# # Compiling All Outdoor Activities by Season

# %%
# This cell is to replicate ma'am's example

def determine_list_state(respo_list):
    if respo_list:
        return respo_list
    

dry_season_oa_dataset = []
rainy_season_oa_dataset = []
# ht = Haven't Tried
ht_oa_dataset = []

# 0 1 2
season_ht_list = ["Dry Season", "Rainy Season"]

for row in data[outdoor_activities_colnames].itertuples():
    respo_ds_oa_answer_list = []
    respo_rs_oa_answer_list = []
    respo_ht_oa_answer_list = []

    for col_name in outdoor_activities_colnames:
        if season_ht_list[0] in getattr(row, col_name):
            respo_ds_oa_answer_list.append(col_name)
        elif season_ht_list[1] in getattr(row, col_name):
            respo_rs_oa_answer_list.append(col_name)
        else:
            respo_ht_oa_answer_list.append(col_name)
        
    dry_season_oa_dataset.append(respo_ds_oa_answer_list)
    rainy_season_oa_dataset.append(respo_rs_oa_answer_list)
    ht_oa_dataset.append(respo_ht_oa_answer_list)


# Remove empty lists inside list.
dry_season_oa_dataset = [x for x in dry_season_oa_dataset if x != []]
rainy_season_oa_dataset = [x for x in rainy_season_oa_dataset if x != []]
ht_oa_dataset = [x for x in ht_oa_dataset if x != []]
    
print(dry_season_oa_dataset)
print("\n")
print(rainy_season_oa_dataset)
print("\n")
print(ht_oa_dataset)
# Out:
# [['Swimming', 'Biking', 'Hiking', 'Basketball', 'Volleyball', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Biking', 'Hiking', 'Volleyball', 'Bungee_Jumping', 'Fishing', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Scuba_Diving', 'Boating', 'Biking', 'Hiking', 'Basketball', 'Volleyball', 'Tennis', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Swimming', 'Scuba_Diving', 'Boating', 'Hiking', 'Basketball', 'Volleyball', 'Golfing', 'Fishing', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Swimming', 'Boating', 'Biking', 'Basketball', 'Volleyball', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Boating', 'Biking', 'Hiking', 'Camping', 'Badminton', 'Sightseeing', 'Picnic'], ['Swimming', 'Scuba_Diving', 'Surfing', 'Wakeboarding', 'Boating', 'Hiking', 'Tennis', 'Camping', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Boating', 'Biking', 'Volleyball', 'Badminton', 'Picnic'], ['Swimming', 'Biking', 'Hiking', 'Basketball', 'Volleyball', 'Tennis', 'Fishing', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Swimming', 'Biking', 'Basketball', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Surfing', 'Boating', 'Biking', 'Hiking', 'Basketball', 'Volleyball', 'Tennis', 'Fishing', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Swimming', 'Boating', 'Biking', 'Hiking', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Scuba_Diving', 'Surfing', 'Wakeboarding', 'Boating', 'Biking', 'Hiking', 'Basketball', 'Volleyball', 'Golfing', 'Sky_Diving', 'Fishing', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Swimming', 'Scuba_Diving', 'Surfing', 'Boating', 'Biking', 'Hiking', 'Tennis', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Swimming', 'Boating', 'Biking', 'Hiking', 'Camping', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Biking', 'Basketball', 'Volleyball', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Boating', 'Biking', 'Basketball', 'Volleyball', 'Fishing', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Boating', 'Biking', 'Volleyball', 'Tennis', 'Camping', 'Badminton', 'Picnic', 'FoodTrip'], ['Swimming', 'Boating', 'Biking', 'Hiking', 'Volleyball', 'Bungee_Jumping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Boating', 'Biking', 'Hiking', 'Basketball', 'Volleyball', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Biking', 'Basketball', 'Tennis', 'Fishing'], ['Swimming', 'Boating', 'Biking', 'Hiking', 'Basketball', 'Volleyball', 'Bungee_Jumping', 'Tennis', 'Badminton', 'Picnic', 'FoodTrip'], ['Swimming', 'Basketball', 'Volleyball', 'Camping', 'Badminton', 'FoodTrip'], ['Swimming', 'Scuba_Diving', 'Boating', 'Biking', 'Hiking', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Swimming', 'Boating', 'Biking', 'Hiking', 'Basketball', 'Volleyball', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Swimming', 'Boating', 'Biking', 'Hiking', 'Fishing', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Swimming', 'Biking', 'Hiking', 'Basketball', 'Volleyball', 'Fishing', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Swimming', 'Volleyball', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Surfing', 'Boating', 'Biking', 'Hiking', 'Basketball', 'Volleyball', 'Tennis', 'Fishing', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimming', 'Boating', 'Biking', 'Hiking', 'Basketball', 'Volleyball', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Swimming', 'Boating', 'Biking', 'Hiking', 'Camping', 'Badminton', 'Sightseeing', 'Picnic', 'FoodTrip'], ['Swimmi ...
#
#
# [['FoodTrip'], ['Biking', 'Fishing', 'Badminton', 'Wildlife_Viewing'], ['Fishing'], ['Tennis'], ['Basketball', 'Volleyball', 'Tennis', 'Badminton'], ['Swimming', 'Wakeboarding', 'Sightseeing'], ['Fishing', 'Camping'], ['Boating'], ['FoodTrip'], ['Hiking', 'Badminton'], ['Biking']]
#
#
# [['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Boating', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing', 'Camping', 'Badminton', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Boating', 'Basketball', 'Golfing', 'Sky_Diving', 'Tennis', 'Wildlife_Viewing'], ['Surfing', 'Wakeboarding', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Fishing'], ['Surfing', 'Wakeboarding', 'Biking', 'Sky_Diving', 'Bungee_Jumping', 'Tennis'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Hiking', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Basketball', 'Volleyball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing', 'Wildlife_Viewing'], ['Basketball', 'Volleyball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Hiking', 'Basketball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Camping', 'Sightseeing', 'FoodTrip', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Boating', 'Golfing', 'Sky_Diving', 'Bungee_Jumping'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Boating', 'Hiking', 'Volleyball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing', 'Camping', 'Wildlife_Viewing'], ['Scuba_Diving', 'Wakeboarding', 'Golfing', 'Sky_Diving', 'Bungee_Jumping'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Basketball', 'Volleyball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing', 'Wildlife_Viewing'], ['Bungee_Jumping'], ['Wakeboarding', 'Basketball', 'Volleyball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Fishing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Fishing', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Boating', 'Hiking', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing', 'Camping', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Hiking', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Camping', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Hiking', 'Basketball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Fishing', 'Sightseeing', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Basketball', 'Golfing', 'Sky_Diving', 'Tennis', 'Fishing', 'Camping', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Boating', 'Hiking', 'Volleyball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Camping', 'Badminton', 'Picnic', 'FoodTrip', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Golfing', 'Sky_Diving', 'Sightseeing', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Biking', 'Hiking', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing', 'Sightseeing', 'Picnic', 'Wildlife_Viewing'], ['Surfing', 'Wakeboarding', 'Basketball', 'Volleyball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Basketball', 'Volleyball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Camping'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Boating', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Boating', 'Biking', 'Hiking', 'Basketball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing', 'Camping', 'Wildlife_Viewing'], ['Scuba_Diving', 'Wakeboarding', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Basketball', 'Volleyball', 'Golfing', 'Sky_Diving', 'Bungee_Jumping', 'Tennis', 'Fishing', 'Wildlife_Viewing'], ['Scuba_Diving', 'Surfing', 'Wakeboarding', 'Basket ...

# %% [raw]
# dry_season_oa_dataset = []
# rainy_season_oa_dataset = []
# ht_oa_dataset = []

# %%
# Determine minimum support for each season
print("Minimum Support for Dry Season O_A: {}".format(len(dry_season_oa_dataset)*60/100))
print("Minimum Support for Rainy Season O_A: {}".format(len(rainy_season_oa_dataset)*60/100))
# Out:
# Minimum Support for Dry Season O_A: 60.6
# Minimum Support for Rainy Season O_A: 6.6

# %%
te1 = TransactionEncoder()
te2 = TransactionEncoder()
te3 = TransactionEncoder()

te_dry_season_oa_dataset = te1.fit(dry_season_oa_dataset).transform(dry_season_oa_dataset)
te_rainy_season_oa_dataset = te2.fit(rainy_season_oa_dataset).transform(rainy_season_oa_dataset)

te_ht_oa_dataset = te3.fit(ht_oa_dataset).transform(ht_oa_dataset)

# %%
df_dry_season_oa_dataset = pd.DataFrame(te_dry_season_oa_dataset, columns=te1.columns_)
df_dry_season_oa_dataset
# Out:
#      Badminton  Basketball  Biking  Boating  Bungee_Jumping  Camping  Fishing  \
# 0        False        True    True    False           False    False    False
# 1         True       False    True    False            True     True     True
# 2         True        True    True     True           False     True    False
# 3         True        True   False     True           False     True     True
# 4         True        True    True     True           False     True    False
# ..         ...         ...     ...      ...             ...      ...      ...
# 96        True        True    True     True           False    False    False
# 97        True        True    True     True           False     True     True
# 98        True        True    True     True            True     True     True
# 99        True       False    True     True           False     True     True
# 100       True        True    True     True            True     True     True
#
#      FoodTrip  Golfing  Hiking  Picnic  Scuba_Diving  Sightseeing  Sky_Diving  \
# 0        True    False    True    True         False         True       False
# 1        True    False    True    True         False         True       False
# 2        True    False    True    True          True         True       False
# 3        True     True    True    True          True         True       False
# 4        True    False   False    True         False         True       False
# ..        ...      ...     ...     ...           ...          ...         ...
# 96       True     True    True    True          True         True       False
# 97       True     True    True    True          True         True       False
# 98       True     True    True    True          True         True        True
# 99       True    False    True    True         False         True       False
# 100      True     True    True    True          True         True        True
#
#      Surfing  Swimming  Tennis  Volleyball  Wakeboarding  Wildlife_Viewing
# 0      False      True   False        True         False             False
# 1      False      True   False        True         False             False
# 2      False      True    True        True         False              True
# 3      False      True   False        True         False              True
# 4      False      True   False        True         False             False
# ..       ...       ...     ...         ...           ...               ...
# 96      True      True   False        True          True              True
# 97      True      True    True        True          True              True
# 98      True      True    True        True          True              True
# 99     False      True    True        True         False              True
# 100     True      True    True        True          True              True
#
# [101 rows x 20 columns]

# %%
df_rainy_season_oa_dataset = pd.DataFrame(te_rainy_season_oa_dataset, columns=te2.columns_)
df_rainy_season_oa_dataset
# Out:
#     Badminton  Basketball  Biking  Boating  Camping  Fishing  FoodTrip  \
# 0       False       False   False    False    False    False      True
# 1        True       False    True    False    False     True     False
# 2       False       False   False    False    False     True     False
# 3       False       False   False    False    False    False     False
# 4        True        True   False    False    False    False     False
# 5       False       False   False    False    False    False     False
# 6       False       False   False    False     True     True     False
# 7       False       False   False     True    False    False     False
# 8       False       False   False    False    False    False      True
# 9        True       False   False    False    False    False     False
# 10      False       False    True    False    False    False     False
#
#     Hiking  Sightseeing  Swimming  Tennis  Volleyball  Wakeboarding  \
# 0    False        False     False   False       False         False
# 1    False        False     False   False       False         False
# 2    False        False     False   False       False         False
# 3    False        False     False    True       False         False
# 4    False        False     False    True        True         False
# 5    False         True      True   False       False          True
# 6    False        False     False   False       False         False
# 7    False        False     False   False       False         False
# 8    False        False     False   False       False         False
# 9     True        False     False   False       False         False
# 10   False        False     False   False       False         False
#
#     Wildlife_Viewing
# 0              False
# 1               True
# 2              False
# 3              False
# 4              False
# 5              False
# 6              False
# 7              False
# 8              False
# 9              False
# 10             False

# %% [markdown]
# # Association Rule Mining P1

# %%
freq_dryseason_itemsets = apriori(df_dry_season_oa_dataset, min_support = 0.606, use_colnames = True)
freq_dryseason_itemsets.sort_values(by=['support']).tail()
# Out:
#      support              itemsets
# 7   0.940594              (Picnic)
# 50  0.940594    (Swimming, Picnic)
# 43  0.960396  (Swimming, FoodTrip)
# 5   0.960396            (FoodTrip)
# 9   0.990099            (Swimming)

# %%
res_dryseason = association_rules(freq_dryseason_itemsets, metric="confidence", min_threshold=1)
res_dryseason[res_dryseason['confidence'] >= 1]
# Out:
#                                            antecedents  \
# 0                                          (Badminton)
# 1                                            (Boating)
# 2                                            (Camping)
# 3                                           (FoodTrip)
# 4                                             (Hiking)
# ..                                                 ...
# 464  (Hiking, Badminton, Biking, FoodTrip, Sightsee...
# 465  (Hiking, Badminton, Biking, Picnic, FoodTrip, ...
# 466  (Hiking, Badminton, Biking, FoodTrip, Sightsee...
# 467  (Hiking, Badminton, Biking, FoodTrip, Swimming...
# 468     (Hiking, Badminton, Biking, FoodTrip, Camping)
#
#                          consequents  antecedent support  consequent support  \
# 0                         (Swimming)            0.881188            0.990099
# 1                         (Swimming)            0.811881            0.990099
# 2                         (Swimming)            0.841584            0.990099
# 3                         (Swimming)            0.960396            0.990099
# 4                         (Swimming)            0.841584            0.990099
# ..                               ...                 ...                 ...
# 464                         (Picnic)            0.643564            0.940594
# 465          (Swimming, Sightseeing)            0.643564            0.930693
# 466               (Swimming, Picnic)            0.643564            0.940594
# 467            (Sightseeing, Picnic)            0.643564            0.910891
# 468  (Sightseeing, Swimming, Picnic)            0.643564            0.910891
#
#       support  confidence      lift  leverage  conviction
# 0    0.881188         1.0  1.010000  0.008725         inf
# 1    0.811881         1.0  1.010000  0.008038         inf
# 2    0.841584         1.0  1.010000  0.008333         inf
# 3    0.960396         1.0  1.010000  0.009509         inf
# 4    0.841584         1.0  1.010000  0.008333         inf
# ..        ...         ...       ...       ...         ...
# 464  0.643564         1.0  1.063158  0.038232         inf
# 465  0.643564         1.0  1.074468  0.044603         inf
# 466  0.643564         1.0  1.063158  0.038232         inf
# 467  0.643564         1.0  1.097826  0.057347         inf
# 468  0.643564         1.0  1.097826  0.057347         inf
#
# [469 rows x 9 columns]

# %% [markdown]
# # Association Rule Mining P2

# %%
freq_rainyseason_itemsets = apriori(df_rainy_season_oa_dataset, min_support = 0.09, use_colnames = True)
freq_rainyseason_itemsets.sort_values(by=['support']).tail()
# Out:
#      support     itemsets
# 10  0.181818     (Tennis)
# 6   0.181818   (FoodTrip)
# 2   0.181818     (Biking)
# 5   0.272727    (Fishing)
# 0   0.272727  (Badminton)

# %%
res_rainyseason = association_rules(freq_rainyseason_itemsets, metric="confidence", min_threshold=1)
res_rainyseason[res_rainyseason['confidence'] >= 1]
# Out:
#                       antecedents                    consequents  \
# 0                    (Basketball)                    (Badminton)
# 1                        (Hiking)                    (Badminton)
# 2                    (Volleyball)                    (Badminton)
# 3              (Wildlife_Viewing)                    (Badminton)
# 4                    (Basketball)                       (Tennis)
# ..                            ...                            ...
# 74  (Badminton, Wildlife_Viewing)              (Biking, Fishing)
# 75              (Biking, Fishing)  (Badminton, Wildlife_Viewing)
# 76     (Biking, Wildlife_Viewing)           (Badminton, Fishing)
# 77    (Fishing, Wildlife_Viewing)            (Badminton, Biking)
# 78             (Wildlife_Viewing)   (Badminton, Biking, Fishing)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.090909            0.272727  0.090909         1.0   3.666667
# 1             0.090909            0.272727  0.090909         1.0   3.666667
# 2             0.090909            0.272727  0.090909         1.0   3.666667
# 3             0.090909            0.272727  0.090909         1.0   3.666667
# 4             0.090909            0.181818  0.090909         1.0   5.500000
# ..                 ...                 ...       ...         ...        ...
# 74            0.090909            0.090909  0.090909         1.0  11.000000
# 75            0.090909            0.090909  0.090909         1.0  11.000000
# 76            0.090909            0.090909  0.090909         1.0  11.000000
# 77            0.090909            0.090909  0.090909         1.0  11.000000
# 78            0.090909            0.090909  0.090909         1.0  11.000000
#
#     leverage  conviction
# 0   0.066116         inf
# 1   0.066116         inf
# 2   0.066116         inf
# 3   0.066116         inf
# 4   0.074380         inf
# ..       ...         ...
# 74  0.082645         inf
# 75  0.082645         inf
# 76  0.082645         inf
# 77  0.082645         inf
# 78  0.082645         inf
#
# [79 rows x 9 columns]

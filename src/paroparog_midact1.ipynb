# %% [markdown]
# # Installations

# %%
# Installations of libraries
# !pip install PyPDF2
# !pip install nltk
# !pip install pdfminer
# !pip install textblob
# !pip install spacy
# !pip install svgutils
# !pip install wordcloud

# !python -m spacy download en_core_web_sm
# !python -m spacy download fr_core_news_md
# Out:
# Requirement already satisfied: PyPDF2 in d:\anaconda3\lib\site-packages (1.26.0)
# Requirement already satisfied: nltk in d:\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: tqdm in d:\anaconda3\lib\site-packages (from nltk) (4.63.0)
# Requirement already satisfied: joblib in d:\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in d:\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda3\lib\site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from click->nltk) (0.4.4)
# Requirement already satisfied: pdfminer in d:\anaconda3\lib\site-packages (20191125)
# Requirement already satisfied: pycryptodome in d:\anaconda3\lib\site-packages (from pdfminer) (3.14.1)
# Requirement already satisfied: textblob in d:\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in d:\anaconda3\lib\site-packages (from textblob) (3.7)
# Requirement already satisfied: tqdm in d:\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.63.0)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.8.3)
# Requirement already satisfied: joblib in d:\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: click in d:\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (8.0.4)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.4)
# Requirement already satisfied: spacy in d:\anaconda3\lib\site-packages (3.2.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\anaconda3\lib\site-packages (from spacy) (2.27.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\anaconda3\lib\site-packages (from spacy) (4.63.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in d:\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from spacy) (58.0.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in d:\anaconda3\lib\site-packages (from spacy) (8.0.15)
# Requirement already satisfied: pathy>=0.3.5 in d:\anaconda3\lib\site-packages (from spacy) (0.6.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in d:\anaconda3\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: numpy>=1.15.0 in d:\anaconda3\lib\site-packages (from spacy) (1.20.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\anaconda3\lib\site-packages (from spacy) (1.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\anaconda3\lib\site-packages (from spacy) (1.0.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in d:\anaconda3\lib\site-packages (from spacy) (0.7.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in d:\anaconda3\lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in d:\anaconda3\lib\site-packages (from spacy) (0.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in d:\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\anaconda3\lib\site-packages (from spacy) (3.0.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in d:\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: svgutils in d:\anaconda3\lib\site-packages (0.3.4)
# Requirement already satisfied: lxml in d:\anaconda3\lib\site-packages (from svgutils) (4.8.0)
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in d:\anaconda3\lib\site-packages (from en-core-web-sm==3.2.0) (3.2.3)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (58.0.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.15)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.63.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.27.1)
# Requirement already satisfied: numpy>=1.15.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.20.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: pathy>=0.3.5 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.9)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.6)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in d:\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.8)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda3\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2022-03-26 23:27:20.927114: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-03-26 23:27:20.933522: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Collecting fr-core-news-md==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_md-3.2.0/fr_core_news_md-3.2.0-py3-none-any.whl (46.9 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in d:\anaconda3\lib\site-packages (from fr-core-news-md==3.2.0) (3.2.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (1.0.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (8.0.15)
# 2022-03-26 23:28:25.023885: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-03-26 23:28:25.023936: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (0.7.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (1.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (2.27.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (1.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (3.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (2.4.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (0.9.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (0.4.0)
# Requirement already satisfied: numpy>=1.15.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (1.20.3)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (0.6.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (4.63.0)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (58.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in d:\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (3.10.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (3.3)
# Requirement already satisfied: colorama in d:\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda3\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->fr-core-news-md==3.2.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('fr_core_news_md')

# %% [markdown]
# # Members

# %% [raw]
# Cabuenas, Michael Luke
# Diño, Karylle Marie
# Domantay, Nico Bernard
# Ferrer, Miguel Patrick
# Madriaga, Jeremy
# Mendoza, Bryan Benchmark
# Napeek, Kaiser Moen

# %% [markdown]
# # IMPORTS

# %%
# Imports
from textblob import TextBlob
from collections import Counter
from pathlib import Path

import spacy
from spacy import displacy
import fr_core_news_md

import pandas as pd

from wordcloud import *
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.text import Tokenizer

import svgutils.transform as st

import os
import en_core_web_sm
import glob
import io
import operator

from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams

# %% [markdown]
# # Documents/PDFs/Texts to Texts

# %%
docu_path = "../res/"

# Path to Generated data
# Always the same
dataset_path = "../data/" 

# Dynamic due to filename
text_path = "../data/per_article_text_files/"
classification_path = "../data/per_article_classification/"
entities_path = "../data/per_article_entities_label/"
render_path = "../data/sentence_render_html/"
entities_visuals_path = "../data/per_article_top_entities_visuals/"

# %%
# Read only documents that ends with .pdf .docx .txt
pdf_files = glob.glob(os.path.join(docu_path, "*.pdf"))
doc_files = glob.glob(os.path.join(docu_path, "*.docx"))
txt_files = glob.glob(os.path.join(docu_path, "*.txt"))
accepted_files = []

accepted_files = [*pdf_files, *doc_files, *txt_files]

# Print Sample File
accepted_files[0]
# Out:
# '../res\\#VaccinesWork_ 488,000 vulnerable children of Basilan, Sulu and Tawi-tawi to receive additional protection from polio.pdf'

# %%
# Function to generate a dictionary with a unique ascending id
def generate_dataset_dictionary(files):
    dict = {"Docu_ID": [], "File_Name": []}
    
    for idx, file in enumerate(files):
        split_file_name = file.split("\\")
        file_name = split_file_name[1]

        dict["Docu_ID"].append("1"+str(idx).zfill(4))
        # dict["Docu_ID"].append(file_name[:len(file_name[idx]) - 5]+"_00"+str(idx))
        dict["File_Name"].append(file_name)
    
    return dict

# %%
document_dict = generate_dataset_dictionary(accepted_files)

# Initial Dataframe
initial_df = pd.DataFrame(document_dict)
initial_df['Docu_ID'] = initial_df['Docu_ID'].astype('str')
initial_df[0:5]
# Out:
#   Docu_ID                                          File_Name
# 0   10000  #VaccinesWork_ 488,000 vulnerable children of ...
# 1   10001  3M Moderna vaccines from US Government arrive ...
# 2   10002       Accelerating efforts to end AIDS by 2030.pdf
# 3   10003  amfAR and WHO Support Pilot Study Investigatin...
# 4   10004  Asia Pacific health and finance ministers stre...

# %%
# Create dataset containing the file names of articles
initial_df.to_csv(dataset_path + "docu_dataset.csv", index=False, header=True)
print("Text File created . Path: {}\n".format(dataset_path + "docu_dataset.csv"))
# Out:
# Text File created . Path: ../data/docu_dataset.csv

# %%
# Function to convert document file to txt file with per line sentences
def pdf_to_text_sentences(pdf_file, docu_id):
    inFile = open(pdf_file, 'rb')
    resMgr = PDFResourceManager()
    retData = io.StringIO()
    TxtConverter = TextConverter(resMgr, retData,laparams = LAParams())
    interpreter = PDFPageInterpreter(resMgr, TxtConverter)

    # Process each pages
    for page in PDFPage.get_pages(inFile): 
        interpreter.process_page(page)


    # Write to text temporary file
    txt = retData.getvalue()

    # Acquire sentences
    blob = TextBlob(txt)
    sentences = []

    # Append to sentences whilest removing 'sentence(...)' on each sentences/list elements
    for s in blob.sentences:
         sentences.append(str(s).strip()),

    cleaned_sentences = []

    # Append to cleaned_sentences whilest removing new lines or '\n'
    for x in sentences:
         cleaned_sentences.append(x.replace("\n", " "))

    # Create and Open new temp text file and write cleaned sentences on a per line basis
    with open(text_path + "txt_" + docu_id + ".txt", 'w', encoding='utf-8') as f: 
        f.write('\n'.join(cleaned_sentences))
        print("Text File created . Path: {}\n".format(text_path + 
                                                      "txt_" + 
                                                      docu_id + 
                                                      ".txt"))
    
    inFile.close()

# %%
# Separate each sentences from the document
# May take some time
for idx in initial_df.index:
    pdf_to_text_sentences(docu_path + str(initial_df["File_Name"][idx]), str(initial_df["Docu_ID"][idx]))
# Out:
# Text File created . Path: ../data/per_article_text_files/txt_10000.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10001.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10002.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10003.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10004.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10005.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10006.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10007.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10008.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10009.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10010.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10011.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10012.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10013.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10014.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10015.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10016.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10017.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10018.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10019.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10020.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10021.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10022.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10023.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10024.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10025.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10026.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10027.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10028.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10029.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10030.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10031.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10032.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10033.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10034.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10035.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10036.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10037.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10038.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10039.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10040.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10041.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10042.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10043.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10044.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10045.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10046.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10047.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10048.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10049.txt
#
# Text File created . Path: ../data/per_article_text_files/txt_10050.txt

# %%
# Generate temporary text files containing per line sentences of a single article
txt_files = glob.glob(os.path.join(text_path, "*.txt"))

text_dict = generate_dataset_dictionary(txt_files)

text_df = pd.DataFrame(text_dict)
text_df[0:5]
# Out:
#   Docu_ID      File_Name
# 0   10000  txt_10000.txt
# 1   10001  txt_10001.txt
# 2   10002  txt_10002.txt
# 3   10003  txt_10003.txt
# 4   10004  txt_10004.txt

# %%
# Write to data folder name = "text_dataset.csv"
text_df.to_csv(dataset_path + "text_dataset.csv", index=False, header=True)
print("CSV File created successfully. Path: {}\n".format(dataset_path + "text_dataset.csv"))
# Out:
# CSV File created successfully. Path: ../data/text_dataset.csv

# %% [markdown]
# # Classify Text File

# %%
# Open File
def open_file(file):
    # Open text file
    raw = open(file, encoding='utf-8').read()

    nlp = en_core_web_sm.load()
    nlp.max_length = 3000000
    
    raw_nlp = nlp(raw)
    
    return raw_nlp

# %%
# Function to determine sentence index of word/element per document when 
# creating another dataset (Can be used for data visualizations)
def split_sentences(raw_nlp):
    sentences = [x for x in raw_nlp.sents]
    sentence_index = []
    
    # Contain tokenized data and its corresponding sentence index
    for idx1 in range(len(sentences)):
        temporary_sentence = sentences[idx1]
        temporary_tokens = [x for x in temporary_sentence]
        
        for idx2, val in enumerate(temporary_tokens):
            sentence_index.append(idx1)
    
    return sentence_index

# %%
# Generate labels dataset (.csv dataset with 2 columns ["Word", "Label"])
def generate_labels_dataset(raw_nlp, docu_id):
    label = ([(x.text, x.label_) for x in raw_nlp.ents])
    word, label = zip(*label)
    labels_df = pd.DataFrame(zip(word, label), columns=["Word", "Label"])
    
    labels_df.to_csv(entities_path + "ent_" + docu_id + ".csv", index=False, header=True)
    print("CSV File created successfully. Path: {}\n".format(entities_path + "ent_" + docu_id + ".csv"))

# %%
# Read from csv
text_df = pd.read_csv(dataset_path + "text_dataset.csv")
# Sample data
text_df[0:2]
# Out:
#    Docu_ID      File_Name
# 0    10000  txt_10000.txt
# 1    10001  txt_10001.txt

# %%
# For every text file, read each sentences/lines and use spacy nlp to classify each entities
for idx in text_df.index:
    raw_nlp = open_file(text_path + str(text_df["File_Name"][idx]))
    sentence_index = split_sentences(raw_nlp)
    generate_labels_dataset(raw_nlp, str(text_df["Docu_ID"][idx]))
    
    # Entity types such as pos tagging, inside-outside-beginning tags, entity types, etc...
    ent_type = ([(x, x.pos_, spacy.explain(x.tag_), x.tag_, x.ent_iob_, x.ent_type_) for x in raw_nlp])
    
    # Words and Tags list
    word, pos, e_tags, tags, iob, e_type = zip(*ent_type)
    
    classification_df = pd.DataFrame(zip(sentence_index, word, pos, e_tags, tags, iob, e_type), 
                      columns=["Sentence_Index", "Token", "Pos", "Explained_Tag", "Tag", "iob_Tag", "Entity_Type"])
    
    # Output to csv, do note that the csv file is for analyzing purposes
    # .csv Dataset with 7 columns: 
    # Sentence_Index (0,0,0,1,1,2, ...)
    # Token (Moderna, vaccines, from, US, Government, ...)
    # Pos (PROPN, ADP, SPACE. NUM, ...)
    # Explained_Tag (cardinal number, punctuation mark, noun, ...)
    # Tag (CD, ., NN, _SP, NNP, ...)
    # iob_Tag (B, O, B, I, O, O, ...)
    # Entity_Type (CARDINAL, TIME, ORG, LOC, ...)
    classification_df.to_csv(str(classification_path)  + "classification_" + 
                             str(text_df["Docu_ID"][idx]) + ".csv", index=False, header=True)
    
    print("CSV File created successfully. Path: {}\n".format(str(classification_path) + 
                                                           "classification_" + 
                                                           str(text_df["Docu_ID"][idx])))
# Out:
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10000.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10000
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10001.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10001
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10002.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10002
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10003.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10003
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10004.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10004
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10005.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10005
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10006.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10006
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10007.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10007
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10008.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10008
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10009.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10009
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10010.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10010
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10011.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10011
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10012.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10012
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10013.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10013
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10014.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10014
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10015.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10015
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10016.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10016
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10017.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10017
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10018.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10018
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10019.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10019
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10020.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10020
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10021.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10021
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10022.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10022
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10023.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10023
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10024.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10024
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10025.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10025
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10026.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10026
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10027.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10027
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10028.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10028
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10029.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10029
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10030.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10030
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10031.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10031
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10032.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10032
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10033.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10033
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10034.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10034
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10035.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10035
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10036.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10036
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10037.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10037
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10038.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10038
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10039.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10039
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10040.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10040
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10041.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10041
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10042.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10042
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10043.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10043
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10044.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10044
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10045.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10045
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10046.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10046
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10047.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10047
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10048.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10048
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10049.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10049
#
# CSV File created successfully. Path: ../data/per_article_entities_label/ent_10050.csv
#
# CSV File created successfully. Path: ../data/per_article_classification/classification_10050

# %% [markdown]
# # Generate Visuals per Sentence

# %%
nlp = spacy.load("en_core_web_sm")

for idx in text_df.index:
    raw_nlp = open_file(text_path + str(text_df["File_Name"][idx]))
    
    counter = 0
    sentences = [x.text for x in raw_nlp.sents]
    
    output_path = Path(render_path + 
                          initial_df["File_Name"][idx][:len(initial_df["File_Name"][idx]) - 4]  
                          + ".html")
    
    # Only read lines with entities for faster classification
    for i in sentences:
        # Process single sentence
        sent = nlp(i)
       
        if sent.ents:
            if counter == 0:
                # Create svg and render one sentence
                svg = displacy.render(sent, jupyter=False, style='ent')
            else:
                # Render to existing svg
                svg = svg + displacy.render(sent, jupyter=False, style='ent')
            counter = counter + 1
        else:
            pass
        
        # Write to html
        output_path.open("w", encoding='utf-8').write(svg)
        
    print("HTML File generated successfully. Path: {}\n".format(output_path))


        # Path to html data folder = data/sentence_render_img
# Out:
# HTML File generated successfully. Path: ..\data\sentence_render_html\#VaccinesWork_ 488,000 vulnerable children of Basilan, Sulu and Tawi-tawi to receive additional protection from polio.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\3M Moderna vaccines from US Government arrive from COVAX Facility.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Accelerating efforts to end AIDS by 2030.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\amfAR and WHO Support Pilot Study Investigating PrEP in the Philippines.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Asia Pacific health and finance ministers stress importance of universal health coverage in COVID-19 era and beyond.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Breastfeeding must continue amidst COVID-19.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Community Innovation to Support Surveillance and Contact Tracing.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Countries race against the clock to overcome antimicrobial resistance (AMR).html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\DOH, LGUs and partners to conduct Phase II of month-long nationwide measles-rubella and oral polio vaccine campaign starting February 1.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\DOH, RITM, WHO establish subnational laboratories to expand the country's capacity in detecting vaccine-preventable diseases.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\DOH, WHO launch Hepatitis B project in Bataan and Pampanga.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\DOH, WHO urge devotees to safely observe Traslacion at home.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\EU and WHO provide lifesaving medical-grade oxygen for preparedness against new COVID-19 variants.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\European Union provides €2.3 million to protect Filipinos from COVID-19.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Food and waterborne diseases threaten 7 million Filipinos without toilet facilities.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\From containment to suppression_ WHO and Lancet COVID-19 Commission highlight lessons from the Western Pacific Region.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Gender equality makes everyone healthier_ WHO.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Germany supports the Philippines with first 844,800 COVID-19 vaccine doses via COVAX.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Health leaders endorse action plan to end TB in the Region.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Health ministers endorse WHO five-year plan to make the Western Pacific the healthiest, safest region.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Hong Kong SAR (China) eliminates rubella.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Investing in mental health benefits people and the economy.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Investment in noncommunicable diseases prevention and control will save lives and contribute to the Philippines saving up to 4.8% of annual GDP.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Malaria prevention works_ Let us close the gap.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Minimizing the impact of the Delta variant in the Philippines.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\More than one million Filipinos have quit tobacco use.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Partnership, protection, response and empowerment_ rolling out essential services to end gender-based violence against women and girls in Asia and the Pacific.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\PH receives first tranche of additional 10M Pfizer doses from COVAX Facility.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\PH Solidarity trial for COVID-19 treatments receives green light from ethics review body.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Polio vaccination must intensify until the last child is reached and fully protected.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Regional health leaders agree on actions to promote health through schools, harness traditional and complementary medicine.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Regional health leaders convene in Japan and online in “hybrid” meeting to agree actions on COVID-19 and other key issues.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Region’s health ministers endorse action to promote access to vaccines, safe surgery and healthy ageing.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Region’s leaders discuss need to protect health in relation to climate change and the environment.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Region’s leaders gather virtually to tackle COVID-19 and other health issues, chart WHO’s work in the Western Pacific.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\UN agencies launch joint programme to support vulnerable women and young people amid COVID-19.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\UN agencies support three-day vaccination drive, remind LGUs to prioritize the most vulnerable.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\UN agencies warn economic impact of COVID-19 and worsening inequalities will fuel malnutrition for billions in Asia and the Pacific.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\UN, UNICEF, WHO and UNESCO welcome the start of limited in-person schooling in the Philippines.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\Urgent need for investment in nursing.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\WHO and EU join together to support COVID-19 response and systems strengthening in Asia.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\WHO Awards Health Secretary Ubial for Tobacco Control.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\WHO hosts dialogue on climate change and health.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\WHO launches Third Progress Report on Global Trans Fat Elimination, features milestones in the Philippines.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\WHO Regional Committee for the Western Pacific notes progress on healthy newborn infants, antimicrobial resistance and essential medicines.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\WHO statement on COVID-19 vaccines and the National Vaccination Days.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\WHO stresses the importance of neonatal best practices for a healthy start to life.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\WHO, UNICEF and partners support Philippine Department of Health’s polio outbreak response.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\who_int_0.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\who_int_1.html
#
# HTML File generated successfully. Path: ..\data\sentence_render_html\World Polio Day_ Government and health partners urge children’s vaccination against all preventable diseases preventable diseases.html

# %% [markdown]
# # Generate Top Tags Per Article

# %% [raw]
# docu_path = "../res/"
#
# # Path to Generated data
# # Always the same
# dataset_path = "../data/"
#
# # Dynamic due to filename
# text_path = "../data/per_article_text_files/"
# classification_path = "../data/per_article_classification/"
# entities_path = "../data/per_article_entities_label/"
# render_path = "../data/sentence_render_html/"
# entities_visuals_path = "../data/per_article_top_entities_visuals/"

# %%
# Retrieve all entities csv file 
# inside the per_article_entities_label folder
ent_csv_files = glob.glob(os.path.join(entities_path, "*.csv"))

# Required major tags list
major_tags_target_list = ["LOC", "PERSON", "ORG", "NORP", "GPE"]

# For each csv files generate a wordcloud of the top 
for idx, ent_csv_f in enumerate(ent_csv_files):
    ent_csv_df = pd.read_csv(ent_csv_f)
    
    output_path = Path(entities_visuals_path + 
                       initial_df["File_Name"][idx][:len(initial_df["File_Name"][idx]) - 4]  
                       + ".png")
    
    # Article's major tags container list
    article_major_tags = []
    
    # Append to article major tag if label is in target list
    for a, b in ent_csv_df.itertuples(index=False):
        if b in major_tags_target_list:
            article_major_tags.append(a)

    # Generate wordcloud and save each article's wordcloud in ../data/per_article_top_entities_visuals
    plt.figure(figsize=(20,14))
    word_cloud = WordCloud(background_color='black',
                           max_font_size = 80).generate(" ".join(article_major_tags[:10]))
    plt.imshow(word_cloud)
    plt.savefig(output_path)
    plt.close()
    
    print("PNG Image generated successfully. Path: {}\n".format(output_path))
# Out:
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\#VaccinesWork_ 488,000 vulnerable children of Basilan, Sulu and Tawi-tawi to receive additional protection from polio.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\3M Moderna vaccines from US Government arrive from COVAX Facility.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Accelerating efforts to end AIDS by 2030.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\amfAR and WHO Support Pilot Study Investigating PrEP in the Philippines.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Asia Pacific health and finance ministers stress importance of universal health coverage in COVID-19 era and beyond.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Breastfeeding must continue amidst COVID-19.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Community Innovation to Support Surveillance and Contact Tracing.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Countries race against the clock to overcome antimicrobial resistance (AMR).png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\DOH, LGUs and partners to conduct Phase II of month-long nationwide measles-rubella and oral polio vaccine campaign starting February 1.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\DOH, RITM, WHO establish subnational laboratories to expand the country's capacity in detecting vaccine-preventable diseases.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\DOH, WHO launch Hepatitis B project in Bataan and Pampanga.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\DOH, WHO urge devotees to safely observe Traslacion at home.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\EU and WHO provide lifesaving medical-grade oxygen for preparedness against new COVID-19 variants.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\European Union provides €2.3 million to protect Filipinos from COVID-19.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Food and waterborne diseases threaten 7 million Filipinos without toilet facilities.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\From containment to suppression_ WHO and Lancet COVID-19 Commission highlight lessons from the Western Pacific Region.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Gender equality makes everyone healthier_ WHO.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Germany supports the Philippines with first 844,800 COVID-19 vaccine doses via COVAX.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Health leaders endorse action plan to end TB in the Region.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Health ministers endorse WHO five-year plan to make the Western Pacific the healthiest, safest region.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Hong Kong SAR (China) eliminates rubella.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Investing in mental health benefits people and the economy.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Investment in noncommunicable diseases prevention and control will save lives and contribute to the Philippines saving up to 4.8% of annual GDP.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Malaria prevention works_ Let us close the gap.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Minimizing the impact of the Delta variant in the Philippines.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\More than one million Filipinos have quit tobacco use.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Partnership, protection, response and empowerment_ rolling out essential services to end gender-based violence against women and girls in Asia and the Pacific.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\PH receives first tranche of additional 10M Pfizer doses from COVAX Facility.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\PH Solidarity trial for COVID-19 treatments receives green light from ethics review body.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Polio vaccination must intensify until the last child is reached and fully protected.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Regional health leaders agree on actions to promote health through schools, harness traditional and complementary medicine.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Regional health leaders convene in Japan and online in “hybrid” meeting to agree actions on COVID-19 and other key issues.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Region’s health ministers endorse action to promote access to vaccines, safe surgery and healthy ageing.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Region’s leaders discuss need to protect health in relation to climate change and the environment.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Region’s leaders gather virtually to tackle COVID-19 and other health issues, chart WHO’s work in the Western Pacific.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\UN agencies launch joint programme to support vulnerable women and young people amid COVID-19.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\UN agencies support three-day vaccination drive, remind LGUs to prioritize the most vulnerable.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\UN agencies warn economic impact of COVID-19 and worsening inequalities will fuel malnutrition for billions in Asia and the Pacific.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\UN, UNICEF, WHO and UNESCO welcome the start of limited in-person schooling in the Philippines.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\Urgent need for investment in nursing.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\WHO and EU join together to support COVID-19 response and systems strengthening in Asia.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\WHO Awards Health Secretary Ubial for Tobacco Control.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\WHO hosts dialogue on climate change and health.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\WHO launches Third Progress Report on Global Trans Fat Elimination, features milestones in the Philippines.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\WHO Regional Committee for the Western Pacific notes progress on healthy newborn infants, antimicrobial resistance and essential medicines.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\WHO statement on COVID-19 vaccines and the National Vaccination Days.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\WHO stresses the importance of neonatal best practices for a healthy start to life.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\WHO, UNICEF and partners support Philippine Department of Health’s polio outbreak response.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\who_int_0.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\who_int_1.png
#
# PNG Image generated successfully. Path: ..\data\per_article_top_entities_visuals\World Polio Day_ Government and health partners urge children’s vaccination against all preventable diseases preventable diseases.png

# %% [markdown]
# # Search using Top Tags/Words (PDF Files only Available in ../res)

# %%
# Function to search tags in entities csv
def search_tags_in_entities_csv(word):
    found_docu_id_dict = {}
    for idx, ent_csv_f in enumerate(ent_csv_files):
        
        # Read an entity csv in ent_csv_files / per_article_entities_label
        ent_csv_df = pd.read_csv(ent_csv_f)
        
        # Count exact word
        word_total_occurence = ent_csv_df["Word"].str.count(r'(?<!\S){}(?!\S)'.format(str(word))).sum()
        
        if word_total_occurence > 0:
            # Retrieve only the document id
            size = len(ent_csv_files[idx])
            extracted_docu_id = ent_csv_files[idx][:size - 4]
            
            found_docu_id_dict[str(extracted_docu_id[-5:])] = word_total_occurence
            
    return found_docu_id_dict

# %%
# Function to search document name through document id
# Ex. Docu_ID: 10000, File_Name: 3M Moderna vaccines...
def search_docu_name_through_docu_id(docu_id):
    docu_id = str(docu_id)
    docu_df = pd.read_csv(dataset_path + "docu_dataset.csv")
    
    for idx, row in docu_df.iterrows():
        if str(row["Docu_ID"]) == docu_id:
            return row["File_Name"]

# %%
# Function to find specific document file to recommend
def find_document_file(filename, search_path):
    results_list = []
    
    for root, dir, files in os.walk(search_path):
        if filename in files:
            results_list.append(os.path.join(root, filename))
    # Remove duplicates if ever
    results_list = list(dict.fromkeys(results_list))
    return results_list

# %%
# Method to make link clickable
# https://www.geeksforgeeks.org/how-to-create-a-table-with-clickable-hyperlink-to-a-local-file-in-pandas/
def make_clickable(url):
    name= os.path.basename(url)
    return '<a href="{}">{}</a>'.format(url,name)

# %%
# Sample simple search module to recommend pdfs available in the library
# Do note that the link is dynamic, so if one were to click the link inside github, it would still 
user_search_input = input("E-Library Search: ")

found_docu_id_dict = search_tags_in_entities_csv(str(user_search_input))

# Sort according to Occurence of word
sorted_found_docu_id_dict = sorted_d = dict(sorted(found_docu_id_dict.items(), 
                                                   key=operator.itemgetter(1),reverse=True))

if bool(sorted_found_docu_id_dict) == False:
    print("\nNo PDFs Can Be Recommended!")
else:
    for k, v in sorted_found_docu_id_dict.items():
        filename = search_docu_name_through_docu_id(k)
        results_list = find_document_file(filename, docu_path)
        
        # Localhost links
        local_links_df = pd.DataFrame({"Hits": v, "Link": results_list})
        
        # Align it to the left for readability
        left_aligned_df = local_links_df.style.set_properties(**{'text-align': 'left'})
        # Align column to the left for readability
        left_aligned_df = left_aligned_df.set_table_styles(
        [dict(selector = 'th', props=[('text-align', 'left')])])
        
        # Display without index
        display(left_aligned_df.hide().format({'Link' : make_clickable}))
# Out:
# E-Library Search:  Manila
# <style type="text/css">
# #T_4ae63 th {
#   text-align: left;
# }
# #T_4ae63_row0_col0, #T_4ae63_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_4ae63">
#   <thead>
#     <tr>
#       <th id="T_4ae63_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_4ae63_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4ae63_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_4ae63_row0_col1" class="data row0 col1" ><a href="../res/amfAR and WHO Support Pilot Study Investigating PrEP in the Philippines.pdf">amfAR and WHO Support Pilot Study Investigating PrEP in the Philippines.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0b1b9 th {
#   text-align: left;
# }
# #T_0b1b9_row0_col0, #T_0b1b9_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_0b1b9">
#   <thead>
#     <tr>
#       <th id="T_0b1b9_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_0b1b9_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0b1b9_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_0b1b9_row0_col1" class="data row0 col1" ><a href="../res/WHO, UNICEF and partners support Philippine Department of Health’s polio outbreak response.pdf">WHO, UNICEF and partners support Philippine Department of Health’s polio outbreak response.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a13b9 th {
#   text-align: left;
# }
# #T_a13b9_row0_col0, #T_a13b9_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_a13b9">
#   <thead>
#     <tr>
#       <th id="T_a13b9_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_a13b9_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a13b9_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_a13b9_row0_col1" class="data row0 col1" ><a href="../res/3M Moderna vaccines from US Government arrive from COVAX Facility.pdf">3M Moderna vaccines from US Government arrive from COVAX Facility.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d37e9 th {
#   text-align: left;
# }
# #T_d37e9_row0_col0, #T_d37e9_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_d37e9">
#   <thead>
#     <tr>
#       <th id="T_d37e9_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_d37e9_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d37e9_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_d37e9_row0_col1" class="data row0 col1" ><a href="../res/Investing in mental health benefits people and the economy.pdf">Investing in mental health benefits people and the economy.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_40ba9 th {
#   text-align: left;
# }
# #T_40ba9_row0_col0, #T_40ba9_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_40ba9">
#   <thead>
#     <tr>
#       <th id="T_40ba9_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_40ba9_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_40ba9_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_40ba9_row0_col1" class="data row0 col1" ><a href="../res/Accelerating efforts to end AIDS by 2030.pdf">Accelerating efforts to end AIDS by 2030.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5d9ee th {
#   text-align: left;
# }
# #T_5d9ee_row0_col0, #T_5d9ee_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_5d9ee">
#   <thead>
#     <tr>
#       <th id="T_5d9ee_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_5d9ee_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5d9ee_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5d9ee_row0_col1" class="data row0 col1" ><a href="../res/Breastfeeding must continue amidst COVID-19.pdf">Breastfeeding must continue amidst COVID-19.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_db410 th {
#   text-align: left;
# }
# #T_db410_row0_col0, #T_db410_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_db410">
#   <thead>
#     <tr>
#       <th id="T_db410_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_db410_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_db410_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_db410_row0_col1" class="data row0 col1" ><a href="../res/Countries race against the clock to overcome antimicrobial resistance (AMR).pdf">Countries race against the clock to overcome antimicrobial resistance (AMR).pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c9b7a th {
#   text-align: left;
# }
# #T_c9b7a_row0_col0, #T_c9b7a_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_c9b7a">
#   <thead>
#     <tr>
#       <th id="T_c9b7a_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_c9b7a_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c9b7a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c9b7a_row0_col1" class="data row0 col1" ><a href="../res/DOH, RITM, WHO establish subnational laboratories to expand the country's capacity in detecting vaccine-preventable diseases.pdf">DOH, RITM, WHO establish subnational laboratories to expand the country's capacity in detecting vaccine-preventable diseases.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_02341 th {
#   text-align: left;
# }
# #T_02341_row0_col0, #T_02341_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_02341">
#   <thead>
#     <tr>
#       <th id="T_02341_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_02341_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_02341_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_02341_row0_col1" class="data row0 col1" ><a href="../res/DOH, WHO urge devotees to safely observe Traslacion at home.pdf">DOH, WHO urge devotees to safely observe Traslacion at home.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a9e68 th {
#   text-align: left;
# }
# #T_a9e68_row0_col0, #T_a9e68_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_a9e68">
#   <thead>
#     <tr>
#       <th id="T_a9e68_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_a9e68_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a9e68_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a9e68_row0_col1" class="data row0 col1" ><a href="../res/EU and WHO provide lifesaving medical-grade oxygen for preparedness against new COVID-19 variants.pdf">EU and WHO provide lifesaving medical-grade oxygen for preparedness against new COVID-19 variants.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_325f9 th {
#   text-align: left;
# }
# #T_325f9_row0_col0, #T_325f9_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_325f9">
#   <thead>
#     <tr>
#       <th id="T_325f9_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_325f9_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_325f9_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_325f9_row0_col1" class="data row0 col1" ><a href="../res/Food and waterborne diseases threaten 7 million Filipinos without toilet facilities.pdf">Food and waterborne diseases threaten 7 million Filipinos without toilet facilities.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_52e60 th {
#   text-align: left;
# }
# #T_52e60_row0_col0, #T_52e60_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_52e60">
#   <thead>
#     <tr>
#       <th id="T_52e60_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_52e60_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_52e60_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_52e60_row0_col1" class="data row0 col1" ><a href="../res/Gender equality makes everyone healthier_ WHO.pdf">Gender equality makes everyone healthier_ WHO.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5952c th {
#   text-align: left;
# }
# #T_5952c_row0_col0, #T_5952c_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_5952c">
#   <thead>
#     <tr>
#       <th id="T_5952c_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_5952c_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5952c_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_5952c_row0_col1" class="data row0 col1" ><a href="../res/Germany supports the Philippines with first 844,800 COVID-19 vaccine doses via COVAX.pdf">Germany supports the Philippines with first 844,800 COVID-19 vaccine doses via COVAX.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b8377 th {
#   text-align: left;
# }
# #T_b8377_row0_col0, #T_b8377_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_b8377">
#   <thead>
#     <tr>
#       <th id="T_b8377_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_b8377_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b8377_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b8377_row0_col1" class="data row0 col1" ><a href="../res/Health leaders endorse action plan to end TB in the Region.pdf">Health leaders endorse action plan to end TB in the Region.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e8014 th {
#   text-align: left;
# }
# #T_e8014_row0_col0, #T_e8014_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_e8014">
#   <thead>
#     <tr>
#       <th id="T_e8014_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_e8014_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e8014_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e8014_row0_col1" class="data row0 col1" ><a href="../res/Malaria prevention works_ Let us close the gap.pdf">Malaria prevention works_ Let us close the gap.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d2272 th {
#   text-align: left;
# }
# #T_d2272_row0_col0, #T_d2272_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_d2272">
#   <thead>
#     <tr>
#       <th id="T_d2272_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_d2272_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d2272_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_d2272_row0_col1" class="data row0 col1" ><a href="../res/Minimizing the impact of the Delta variant in the Philippines.pdf">Minimizing the impact of the Delta variant in the Philippines.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ae27e th {
#   text-align: left;
# }
# #T_ae27e_row0_col0, #T_ae27e_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_ae27e">
#   <thead>
#     <tr>
#       <th id="T_ae27e_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_ae27e_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ae27e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ae27e_row0_col1" class="data row0 col1" ><a href="../res/More than one million Filipinos have quit tobacco use.pdf">More than one million Filipinos have quit tobacco use.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7f028 th {
#   text-align: left;
# }
# #T_7f028_row0_col0, #T_7f028_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_7f028">
#   <thead>
#     <tr>
#       <th id="T_7f028_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_7f028_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f028_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7f028_row0_col1" class="data row0 col1" ><a href="../res/PH receives first tranche of additional 10M Pfizer doses from COVAX Facility.pdf">PH receives first tranche of additional 10M Pfizer doses from COVAX Facility.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_20a5d th {
#   text-align: left;
# }
# #T_20a5d_row0_col0, #T_20a5d_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_20a5d">
#   <thead>
#     <tr>
#       <th id="T_20a5d_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_20a5d_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_20a5d_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_20a5d_row0_col1" class="data row0 col1" ><a href="../res/Region’s leaders gather virtually to tackle COVID-19 and other health issues, chart WHO’s work in the Western Pacific.pdf">Region’s leaders gather virtually to tackle COVID-19 and other health issues, chart WHO’s work in the Western Pacific.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_89413 th {
#   text-align: left;
# }
# #T_89413_row0_col0, #T_89413_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_89413">
#   <thead>
#     <tr>
#       <th id="T_89413_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_89413_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_89413_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_89413_row0_col1" class="data row0 col1" ><a href="../res/UN agencies launch joint programme to support vulnerable women and young people amid COVID-19.pdf">UN agencies launch joint programme to support vulnerable women and young people amid COVID-19.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f85ab th {
#   text-align: left;
# }
# #T_f85ab_row0_col0, #T_f85ab_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_f85ab">
#   <thead>
#     <tr>
#       <th id="T_f85ab_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_f85ab_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f85ab_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_f85ab_row0_col1" class="data row0 col1" ><a href="../res/UN agencies support three-day vaccination drive, remind LGUs to prioritize the most vulnerable.pdf">UN agencies support three-day vaccination drive, remind LGUs to prioritize the most vulnerable.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b7694 th {
#   text-align: left;
# }
# #T_b7694_row0_col0, #T_b7694_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_b7694">
#   <thead>
#     <tr>
#       <th id="T_b7694_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_b7694_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b7694_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b7694_row0_col1" class="data row0 col1" ><a href="../res/UN, UNICEF, WHO and UNESCO welcome the start of limited in-person schooling in the Philippines.pdf">UN, UNICEF, WHO and UNESCO welcome the start of limited in-person schooling in the Philippines.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_23bd8 th {
#   text-align: left;
# }
# #T_23bd8_row0_col0, #T_23bd8_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_23bd8">
#   <thead>
#     <tr>
#       <th id="T_23bd8_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_23bd8_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_23bd8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_23bd8_row0_col1" class="data row0 col1" ><a href="../res/WHO Awards Health Secretary Ubial for Tobacco Control.pdf">WHO Awards Health Secretary Ubial for Tobacco Control.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_88426 th {
#   text-align: left;
# }
# #T_88426_row0_col0, #T_88426_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_88426">
#   <thead>
#     <tr>
#       <th id="T_88426_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_88426_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_88426_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_88426_row0_col1" class="data row0 col1" ><a href="../res/WHO hosts dialogue on climate change and health.pdf">WHO hosts dialogue on climate change and health.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_254bc th {
#   text-align: left;
# }
# #T_254bc_row0_col0, #T_254bc_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_254bc">
#   <thead>
#     <tr>
#       <th id="T_254bc_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_254bc_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_254bc_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_254bc_row0_col1" class="data row0 col1" ><a href="../res/WHO launches Third Progress Report on Global Trans Fat Elimination, features milestones in the Philippines.pdf">WHO launches Third Progress Report on Global Trans Fat Elimination, features milestones in the Philippines.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3dfd3 th {
#   text-align: left;
# }
# #T_3dfd3_row0_col0, #T_3dfd3_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_3dfd3">
#   <thead>
#     <tr>
#       <th id="T_3dfd3_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_3dfd3_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3dfd3_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3dfd3_row0_col1" class="data row0 col1" ><a href="../res/WHO Regional Committee for the Western Pacific notes progress on healthy newborn infants, antimicrobial resistance and essential medicines.pdf">WHO Regional Committee for the Western Pacific notes progress on healthy newborn infants, antimicrobial resistance and essential medicines.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_db136 th {
#   text-align: left;
# }
# #T_db136_row0_col0, #T_db136_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_db136">
#   <thead>
#     <tr>
#       <th id="T_db136_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_db136_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_db136_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_db136_row0_col1" class="data row0 col1" ><a href="../res/WHO stresses the importance of neonatal best practices for a healthy start to life.pdf">WHO stresses the importance of neonatal best practices for a healthy start to life.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ded0a th {
#   text-align: left;
# }
# #T_ded0a_row0_col0, #T_ded0a_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_ded0a">
#   <thead>
#     <tr>
#       <th id="T_ded0a_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_ded0a_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ded0a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ded0a_row0_col1" class="data row0 col1" ><a href="../res/who_int_0.pdf">who_int_0.pdf</a></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_597e7 th {
#   text-align: left;
# }
# #T_597e7_row0_col0, #T_597e7_row0_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_597e7">
#   <thead>
#     <tr>
#       <th id="T_597e7_level0_col0" class="col_heading level0 col0" >Hits</th>
#       <th id="T_597e7_level0_col1" class="col_heading level0 col1" >Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_597e7_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_597e7_row0_col1" class="data row0 col1" ><a href="../res/who_int_1.pdf">who_int_1.pdf</a></td>
#     </tr>
#   </tbody>
# </table>

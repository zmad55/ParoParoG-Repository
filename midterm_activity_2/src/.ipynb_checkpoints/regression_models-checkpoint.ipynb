# %%
# APIs/Packages
import pandas as pd
import seaborn as sns

from tabulate import tabulate
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
random_state = 42

# %%
car_data = pd.read_csv("../data/car-data.csv")

from sklearn.preprocessing import LabelEncoder
le_fuel = LabelEncoder()
le_seller = LabelEncoder()
le_transmission = LabelEncoder()

# %%
# Change strings to values (0s, 1s, 2s, etc...)
car_data["le_fuel"] = le_fuel.fit_transform(car_data["Fuel_Type"])
car_data["le_seller"] = le_seller.fit_transform(car_data["Seller_Type"])
car_data["le_transmission"] = le_transmission.fit_transform(car_data["Transmission"])

# Drop previous columns
clean_car_data = car_data.drop(["Fuel_Type", "Seller_Type", "Transmission"], axis='columns')

clean_car_data = clean_car_data[["Car_Name", "Year", "Selling_Price", 
                                 "Present_Price", "Kms_Driven", "le_fuel", 
                                 "le_seller", "le_transmission", "Owner"]]

clean_car_data.rename(columns={"le_fuel": "Fuel_Type", 
                                     "le_seller": "Seller_Type", 
                                     "le_transmission": "Transmission"}, inplace=True)
clean_car_data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          2
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          2
# 3    wagon r  2011           2.85           4.15        5200          2
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          2
# 298     city  2009           3.35          11.00       87934          2
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          2
#
#      Seller_Type  Transmission  Owner
# 0              0             1      0
# 1              0             1      0
# 2              0             1      0
# 3              0             1      0
# 4              0             1      0
# ..           ...           ...    ...
# 296            0             1      0
# 297            0             1      0
# 298            0             1      0
# 299            0             1      0
# 300            0             1      0
#
# [301 rows x 9 columns]

# %%
clean_car_data.to_csv("../data/" + "clean_car_data.csv", index=False, header=True)

# %%
# Contain x train-test and y train-test
x_train, x_test = train_test_split(clean_car_data, 
                                   train_size=0.80, 
                                   test_size=0.20)

# %%
x_train
# Out:
#                  Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 63               fortuner  2015          23.50          35.96       47000
# 236                   eon  2016           3.10           4.43       11849
# 120    Bajaj Pulsar RS200  2016           1.05           1.26        5700
# 144  Bajaj Pulsar  NS 200  2014           0.60           0.99       25000
# 46                   ritz  2013           2.65           4.89       64532
# ..                    ...   ...            ...            ...         ...
# 138  Honda CB Hornet 160R  2016           0.60           0.87       15000
# 210                   i10  2012           3.10           4.60       35775
# 208                   i20  2017           7.90           8.10        3435
# 219                 verna  2012           4.50           9.40       36000
# 148    Bajaj Pulsar 220 F  2010           0.52           0.94       45000
#
#      Fuel_Type  Seller_Type  Transmission  Owner
# 63           1            0             0      0
# 236          2            0             1      0
# 120          2            1             1      0
# 144          2            1             1      0
# 46           2            0             1      0
# ..         ...          ...           ...    ...
# 138          2            1             1      0
# 210          2            0             1      0
# 208          2            0             1      0
# 219          2            0             1      0
# 148          2            1             1      0
#
# [240 rows x 9 columns]

# %%
x_test
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 296                       city  2016           9.50          11.60
# 141   Bajaj Avenger 150 street  2016           0.60           0.80
# 108  Royal Enfield Thunder 350  2016           1.20           1.50
# 89                     etios g  2014           4.75           6.76
# 5                vitara brezza  2018           9.25           9.83
# ..                         ...   ...            ...            ...
# 128       Honda CB Hornet 160R  2017           0.80           0.87
# 11                        ciaz  2015           6.85          10.38
# 73                  etios liva  2011           2.65           5.71
# 169       Hero Splender iSmart  2015           0.40           0.54
# 91                      innova  2014          11.25          16.09
#
#      Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner
# 296       33988          1            0             1      0
# 141       20000          2            1             1      0
# 108       18000          2            1             1      0
# 89        40000          2            0             1      0
# 5          2071          1            0             1      0
# ..          ...        ...          ...           ...    ...
# 128        3000          2            1             1      0
# 11        51000          1            0             1      0
# 73        43000          2            0             1      0
# 169       14000          2            1             1      0
# 91        58242          1            0             1      0
#
# [61 rows x 9 columns]

# %%
plt.figure(figsize=(8,5))

plt.subplot(1,2,1)
plt.title('Car Selling Price Distribution Plot')
sns.distplot(x_train["Selling_Price"])
# Out:
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Car Selling Price Distribution Plot'}, xlabel='Selling_Price', ylabel='Density'>

# %%
plt.figure(figsize=(8,5))

plt.subplot(1,2,1)
plt.title('Car Selling Price Distribution Plot')
sns.distplot(x_test["Selling_Price"])
# Out:
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Car Selling Price Distribution Plot'}, xlabel='Selling_Price', ylabel='Density'>

# %%
plt.figure(figsize=(8,5))

plt.title('Car Selling Price Spread')
sns.boxplot(y=x_train["Selling_Price"])
plt.show()
print(x_train["Selling_Price"].describe())
# Out:
# count    240.000000
# mean       4.655375
# std        5.399894
# min        0.100000
# 25%        0.742500
# 50%        3.470000
# 75%        5.912500
# max       35.000000
# Name: Selling_Price, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.title('Car Selling Price Spread')
sns.boxplot(y=x_test["Selling_Price"])
plt.show()
print(x_test["Selling_Price"].describe())
# Out:
# count    61.000000
# mean      4.684590
# std       3.608977
# min       0.200000
# 25%       1.200000
# 50%       4.500000
# 75%       6.850000
# max      14.900000
# Name: Selling_Price, dtype: float64

# %%
car_data = clean_car_data

# %%
compile_corr_car_data = car_data.corr()
compile_corr_car_data.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f958c_row0_col0, #T_f958c_row1_col1, #T_f958c_row2_col2, #T_f958c_row3_col3, #T_f958c_row4_col4, #T_f958c_row5_col5, #T_f958c_row6_col6, #T_f958c_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f958c_row0_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_f958c_row0_col2 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_f958c_row0_col3, #T_f958c_row0_col7, #T_f958c_row1_col4, #T_f958c_row1_col5, #T_f958c_row1_col6, #T_f958c_row3_col0, #T_f958c_row5_col1, #T_f958c_row5_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f958c_row0_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_f958c_row0_col5 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_f958c_row0_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_f958c_row1_col0 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_f958c_row1_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_f958c_row1_col3 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_f958c_row1_col7 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_f958c_row2_col0, #T_f958c_row5_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_f958c_row2_col1 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_f958c_row2_col3 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_f958c_row2_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_f958c_row2_col5, #T_f958c_row4_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_f958c_row2_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_f958c_row2_col7 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f958c_row3_col1, #T_f958c_row7_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_f958c_row3_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_f958c_row3_col4, #T_f958c_row3_col7 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_f958c_row3_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_f958c_row3_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_f958c_row4_col0 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_f958c_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_f958c_row4_col3, #T_f958c_row6_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_f958c_row4_col5 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_f958c_row4_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_f958c_row4_col7 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_f958c_row5_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_f958c_row5_col3 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_f958c_row5_col4 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_f958c_row5_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_f958c_row6_col0, #T_f958c_row7_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_f958c_row6_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_f958c_row6_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_f958c_row6_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_f958c_row6_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_f958c_row6_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_f958c_row7_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_f958c_row7_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_f958c_row7_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_f958c_row7_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_f958c_row7_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f958c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f958c_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_f958c_level0_col1" class="col_heading level0 col1" >Selling_Price</th>
#       <th id="T_f958c_level0_col2" class="col_heading level0 col2" >Present_Price</th>
#       <th id="T_f958c_level0_col3" class="col_heading level0 col3" >Kms_Driven</th>
#       <th id="T_f958c_level0_col4" class="col_heading level0 col4" >Fuel_Type</th>
#       <th id="T_f958c_level0_col5" class="col_heading level0 col5" >Seller_Type</th>
#       <th id="T_f958c_level0_col6" class="col_heading level0 col6" >Transmission</th>
#       <th id="T_f958c_level0_col7" class="col_heading level0 col7" >Owner</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f958c_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_f958c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f958c_row0_col1" class="data row0 col1" >0.236141</td>
#       <td id="T_f958c_row0_col2" class="data row0 col2" >-0.047584</td>
#       <td id="T_f958c_row0_col3" class="data row0 col3" >-0.524342</td>
#       <td id="T_f958c_row0_col4" class="data row0 col4" >-0.053643</td>
#       <td id="T_f958c_row0_col5" class="data row0 col5" >-0.039896</td>
#       <td id="T_f958c_row0_col6" class="data row0 col6" >0.000394</td>
#       <td id="T_f958c_row0_col7" class="data row0 col7" >-0.182104</td>
#     </tr>
#     <tr>
#       <th id="T_f958c_level0_row1" class="row_heading level0 row1" >Selling_Price</th>
#       <td id="T_f958c_row1_col0" class="data row1 col0" >0.236141</td>
#       <td id="T_f958c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f958c_row1_col2" class="data row1 col2" >0.878983</td>
#       <td id="T_f958c_row1_col3" class="data row1 col3" >0.029187</td>
#       <td id="T_f958c_row1_col4" class="data row1 col4" >-0.509467</td>
#       <td id="T_f958c_row1_col5" class="data row1 col5" >-0.550724</td>
#       <td id="T_f958c_row1_col6" class="data row1 col6" >-0.367128</td>
#       <td id="T_f958c_row1_col7" class="data row1 col7" >-0.088344</td>
#     </tr>
#     <tr>
#       <th id="T_f958c_level0_row2" class="row_heading level0 row2" >Present_Price</th>
#       <td id="T_f958c_row2_col0" class="data row2 col0" >-0.047584</td>
#       <td id="T_f958c_row2_col1" class="data row2 col1" >0.878983</td>
#       <td id="T_f958c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f958c_row2_col3" class="data row2 col3" >0.203647</td>
#       <td id="T_f958c_row2_col4" class="data row2 col4" >-0.440415</td>
#       <td id="T_f958c_row2_col5" class="data row2 col5" >-0.512030</td>
#       <td id="T_f958c_row2_col6" class="data row2 col6" >-0.348715</td>
#       <td id="T_f958c_row2_col7" class="data row2 col7" >0.008057</td>
#     </tr>
#     <tr>
#       <th id="T_f958c_level0_row3" class="row_heading level0 row3" >Kms_Driven</th>
#       <td id="T_f958c_row3_col0" class="data row3 col0" >-0.524342</td>
#       <td id="T_f958c_row3_col1" class="data row3 col1" >0.029187</td>
#       <td id="T_f958c_row3_col2" class="data row3 col2" >0.203647</td>
#       <td id="T_f958c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f958c_row3_col4" class="data row3 col4" >-0.166801</td>
#       <td id="T_f958c_row3_col5" class="data row3 col5" >-0.101419</td>
#       <td id="T_f958c_row3_col6" class="data row3 col6" >-0.162510</td>
#       <td id="T_f958c_row3_col7" class="data row3 col7" >0.089216</td>
#     </tr>
#     <tr>
#       <th id="T_f958c_level0_row4" class="row_heading level0 row4" >Fuel_Type</th>
#       <td id="T_f958c_row4_col0" class="data row4 col0" >-0.053643</td>
#       <td id="T_f958c_row4_col1" class="data row4 col1" >-0.509467</td>
#       <td id="T_f958c_row4_col2" class="data row4 col2" >-0.440415</td>
#       <td id="T_f958c_row4_col3" class="data row4 col3" >-0.166801</td>
#       <td id="T_f958c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_f958c_row4_col5" class="data row4 col5" >0.352415</td>
#       <td id="T_f958c_row4_col6" class="data row4 col6" >0.080466</td>
#       <td id="T_f958c_row4_col7" class="data row4 col7" >0.055705</td>
#     </tr>
#     <tr>
#       <th id="T_f958c_level0_row5" class="row_heading level0 row5" >Seller_Type</th>
#       <td id="T_f958c_row5_col0" class="data row5 col0" >-0.039896</td>
#       <td id="T_f958c_row5_col1" class="data row5 col1" >-0.550724</td>
#       <td id="T_f958c_row5_col2" class="data row5 col2" >-0.512030</td>
#       <td id="T_f9

# %%
sns.heatmap(compile_corr_car_data, annot=True, cmap="Blues", fmt='.1g')
# Out:
# <AxesSubplot:>

# %%
sns.lmplot(x="Year", y="Selling_Price", data=car_data);
car_data["Selling_Price"].corr(car_data["Year"])
# Out:
# 0.23614098016042737

# %%
sns.lmplot(x="Present_Price", y="Selling_Price", data=car_data)
car_data["Selling_Price"].corr(car_data["Present_Price"])
# Out:
# 0.8789825451614951

# %%
sns.lmplot(x="Kms_Driven", y="Selling_Price", data=car_data)
car_data["Selling_Price"].corr(car_data["Kms_Driven"])
# Out:
# 0.029187090674291236

# %%
sns.lmplot(x="Fuel_Type", y="Selling_Price", data=car_data)
car_data["Selling_Price"].corr(car_data["Fuel_Type"])
# Out:
# -0.50946725693251

# %%
sns.lmplot(x="Seller_Type", y="Selling_Price", data=car_data)
car_data["Selling_Price"].corr(car_data["Seller_Type"])
# Out:
# -0.5507237615778758

# %%
sns.lmplot(x="Transmission", y="Selling_Price", data=car_data)
car_data["Selling_Price"].corr(car_data["Transmission"])
# Out:
# -0.3671276333090721

# %%
sns.lmplot(x="Owner", y="Selling_Price", data=car_data)
car_data["Selling_Price"].corr(car_data["Owner"])
# Out:
# -0.0883440990872023

# %%
clean_car_data = clean_car_data.drop("Car_Name", axis=1)

# %%
from sklearn.model_selection import train_test_split

x = np.array(clean_car_data["Present_Price"])
y = np.array(clean_car_data["Selling_Price"])

x_train, x_test, y_train, y_test = train_test_split(x.reshape(-1, 1), y.reshape(-1, 1), 
                                                    train_size = 0.80, 
                                                    test_size = 0.20)

# %%
from sklearn.linear_model import LinearRegression

lreg = LinearRegression(normalize=True).fit(x_train, y_train)
print(lreg.score(x_train, y_train))
print(lreg.score(x_test, y_test))
# Out:
# 0.7775195936234505
# 0.7078039277239416
# D:\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(

# %%
np.set_printoptions(suppress=True)
selling_price_predict = lreg.predict(x_test)
selling_price_predict

sidebyside = pd.DataFrame({"Actual": y_test.flatten(), 
                           "Predicted": selling_price_predict.flatten()})
sidebyside
# Out:
#     Actual  Predicted
# 0     3.49   7.661540
# 1     0.55   1.168452
# 2     0.72   1.251966
# 3     7.50   5.888788
# 4     0.35   1.933400
# ..     ...        ...
# 56    5.50   4.894817
# 57    0.35   1.057271
# 58    5.65   4.812840
# 59    3.10   3.122066
# 60    6.25   4.659134
#
# [61 rows x 2 columns]

# %%
selling_price_predict
# Out:
# array([[ 7.66153993],
#        [ 1.16845207],
#        [ 1.2519661 ],
#        [ 5.8887881 ],
#        [ 1.93339961],
#        [10.26430852],
#        [ 4.71036925],
#        [ 1.6772216 ],
#        [10.30017344],
#        [ 1.21097762],
#        [ 4.91531166],
#        [ 1.24684254],
#        [ 2.53797972],
#        [ 4.24412527],
#        [ 2.14346558],
#        [ 5.58137448],
#        [ 6.93399438],
#        [ 5.17661323],
#        [ 3.03496506],
#        [ 8.39420904],
#        [ 1.18843396],
#        [ 1.38005511],
#        [ 7.73326978],
#        [ 1.51839123],
#        [ 6.29354935],
#        [ 9.00903627],
#        [ 4.85382893],
#        [ 1.1494949 ],
#        [ 1.53376191],
#        [ 1.19560694],
#        [ 1.0982593 ],
#        [ 3.12206558],
#        [ 5.58137448],
#        [ 2.78903417],
#        [ 1.38005511],
#        [ 1.19560694],
#        [ 1.19560694],
#        [ 4.71549281],
#        [ 1.2519661 ],
#        [ 7.93821218],
#        [ 7.16967815],
#        [ 1.18843396],
#        [ 7.73326978],
#        [ 4.65913365],
#        [ 4.25949595],
#        [ 5.8887881 ],
#        [ 4.89481742],
#        [ 5.80168757],
#        [ 4.24412527],
#        [ 3.6856572 ],
#        [ 1.58499752],
#        [ 4.35172003],
#        [ 3.62929804],
#        [ 3.03496506],
#        [ 4.24924883],
#        [ 1.1494949 ],
#        [ 4.89481742],
#        [ 1.05727081],
#        [ 4.81284045],
#        [ 3.12206558],
#        [ 4.65913365]])

# %%
sns.regplot(y_test, selling_price_predict)
plt.xlabel("Predicted Selling Price")
plt.ylabel("Present Price")
plt.show
sidebyside["Predicted"].corr(sidebyside["Actual"])
# Out:
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.846792263132314

# %% [markdown]
# # CREDIT CARD

# %%
# APIs/Packages
import pandas as pd
import seaborn as sns
import numpy as np

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

from sklearn.metrics import silhouette_score, silhouette_samples
from yellowbrick.cluster import SilhouetteVisualizer
from yellowbrick.cluster import KElbowVisualizer

# %%
# Uncleaned Data / Initial Data
ini_credit_card_data = pd.read_csv("../data/Credit card.csv")
ini_credit_card_data.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
ini_credit_card_data.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %%
# Populate n/a values with its column's mean
cl_mean_value = ini_credit_card_data['CREDIT_LIMIT'].mean()
ini_credit_card_data["CREDIT_LIMIT"] = ini_credit_card_data["CREDIT_LIMIT"].fillna(cl_mean_value)

mp_mean_value = ini_credit_card_data['MINIMUM_PAYMENTS'].mean()
ini_credit_card_data["MINIMUM_PAYMENTS"]=ini_credit_card_data["MINIMUM_PAYMENTS"].fillna(mp_mean_value)

# %%
# Drop customer ID as it won't be necessary
credit_card_data = ini_credit_card_data.drop("CUST_ID", axis = 1)
credit_card_data.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
scaler = StandardScaler()
cc_data_scaled = scaler.fit_transform(credit_card_data)
cc_data_scaled
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %%
K = range(1, 11)
wcss = []
for k in K:
    km = KMeans(n_clusters=k, 
                init="k-means++", 
                random_state=3)
    km.fit(cc_data_scaled)
    wcss.append(km.inertia_)
wcss
# Out:
# [152149.99999999994,
#  127784.81000434519,
#  111986.18426023598,
#  99073.93826774825,
#  91502.27452319681,
#  84850.39897130549,
#  79529.20719265059,
#  75569.44343168712,
#  71077.69369710945,
#  66480.72447208336]

# %%
plt.figure(figsize=(10,8))
plt.plot(range(1, 11), wcss,
marker='o', linestyle='--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS Scores')
plt.title('K-Means Clustering')
plt.show()

# %%
for n_clusters in range(2, 11):
    km = KMeans(n_clusters = n_clusters, 
                random_state=3).fit(cc_data_scaled)
    labels = km.labels_
    
    score = silhouette_score(cc_data_scaled, 
                             labels, 
                             metric = "euclidean")
    
    print("For Clusters {}, silhouette score is {}".format(n_clusters, score))
# Out:
# For Clusters 2, silhouette score is 0.20959025073067575
# For Clusters 3, silhouette score is 0.25014574505695786
# For Clusters 4, silhouette score is 0.1976074492720698
# For Clusters 5, silhouette score is 0.19331109052201165
# For Clusters 6, silhouette score is 0.2023890033166003
# For Clusters 7, silhouette score is 0.21439999318589098
# For Clusters 8, silhouette score is 0.20853465664037898
# For Clusters 9, silhouette score is 0.2152266443710712
# For Clusters 10, silhouette score is 0.22422962620039724

# %%
km = KMeans (n_clusters = 3)
visuals_plot = SilhouetteVisualizer(km, 
                                    colors="yellowbrick")

visuals_plot.fit(cc_data_scaled)
visuals_plot.poof()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 8950 Samples in 3 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
visuals_plot = KElbowVisualizer(km, 
                                k=(2,11),
                                locate_elbow=True,
                                metric = 'silhouette')

visuals_plot.fit(cc_data_scaled)
visuals_plot.poof()
# Out:
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
km = KMeans(n_clusters = 3)
km.fit(cc_data_scaled)
# Out:
# KMeans(n_clusters=3)

# %%
km_data = credit_card_data.copy()
km_data['KMeans Segment'] = km.labels_
km_data['KMeans Segment']

cc_data_clust = km_data.groupby('KMeans Segment').mean()

# Display columns as index and index as columns for better readability
cc_data_clust_t = cc_data_clust.transpose()
cc_data_clust_t
# Out:
# KMeans Segment                              0            1            2
# BALANCE                           3990.232159  2197.296209   800.167868
# BALANCE_FREQUENCY                    0.957980     0.981438     0.834788
# PURCHASES                          384.777726  4233.043267   502.262838
# ONEOFF_PURCHASES                   248.730163  2697.663874   250.387735
# INSTALLMENTS_PURCHASES             136.125050  1535.858626   252.196794
# CASH_ADVANCE                      3869.733380   455.603491   330.119045
# PURCHASES_FREQUENCY                  0.232865     0.948701     0.463653
# ONEOFF_PURCHASES_FREQUENCY           0.110942     0.669259     0.130616
# PURCHASES_INSTALLMENTS_FREQUENCY     0.144869     0.739333     0.344946
# CASH_ADVANCE_FREQUENCY               0.447281     0.062830     0.068341
# CASH_ADVANCE_TRX                    12.390351     1.523163     1.211898
# PURCHASES_TRX                        5.628446    56.112620     8.590134
# CREDIT_LIMIT                      6684.526658  7687.659744  3266.448383
# PAYMENTS                          3018.006479  4118.077849   907.745931
# MINIMUM_PAYMENTS                  1795.728205  1214.668536   548.656396
# PRC_FULL_PAYMENT                     0.033774     0.301078     0.154850
# TENURE                              11.350877    11.916933    11.478859

# %%
def low_med_high(a, b, c):
    if(a > b and a > c and b > c):
        return ["H", "M", "L"]
    if(a > b and a > c and b < c):
        return ["H", "L", "M"]
    if(b > a and b > c and c > a):
        return ["L", "H", "M"]
    if(b > a and b > c and c < a):
        return ["M", "H", "L"]
    if(c > a and c > b and b > a):
        return ["L", "M", "H"]
    if(c > a and c > b and b < a):
        return ["M", "L", "H"]

counter = 0
format_c = cc_data_clust_t.copy()
for i, row in format_c.iterrows():
    a = cc_data_clust_t[0][counter]
    b = cc_data_clust_t[1][counter]
    c = cc_data_clust_t[2][counter]
    
    lmh_list = low_med_high(a, b, c)

    format_c[0] = format_c[0].replace(format_c[0][counter], lmh_list[0])
    format_c[1] = format_c[1].replace(format_c[1][counter], lmh_list[1])
    format_c[2] = format_c[2].replace(format_c[2][counter], lmh_list[2])
    
    counter += 1
    
format_c
# Out:
# KMeans Segment                    0  1  2
# BALANCE                           H  M  L
# BALANCE_FREQUENCY                 M  H  L
# PURCHASES                         L  H  M
# ONEOFF_PURCHASES                  L  H  M
# INSTALLMENTS_PURCHASES            L  H  M
# CASH_ADVANCE                      H  M  L
# PURCHASES_FREQUENCY               L  H  M
# ONEOFF_PURCHASES_FREQUENCY        L  H  M
# PURCHASES_INSTALLMENTS_FREQUENCY  L  H  M
# CASH_ADVANCE_FREQUENCY            H  L  M
# CASH_ADVANCE_TRX                  H  M  L
# PURCHASES_TRX                     L  H  M
# CREDIT_LIMIT                      M  H  L
# PAYMENTS                          M  H  L
# MINIMUM_PAYMENTS                  H  M  L
# PRC_FULL_PAYMENT                  L  H  M
# TENURE                            L  H  M

# %%
plt.figure(figsize=(12,8))
x = km_data["BALANCE"]
y = km_data["PURCHASES"]
snss = sns.scatterplot(y, x, hue = km_data["KMeans Segment"])
plt.show
# Out:
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ss_cc_data = pd.DataFrame(StandardScaler().fit_transform(credit_card_data), 
                          columns=credit_card_data.columns)
ss_cc_data
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    -0.731989          -0.249434  -0.424900         -0.356934
# 1     0.786961           0.134325  -0.469552         -0.356934
# 2     0.447135           0.518084  -0.107668          0.108889
# 3     0.049099          -1.016953   0.232058          0.546189
# 4    -0.358775           0.518084  -0.462063         -0.347294
# ...        ...                ...        ...               ...
# 8945 -0.737950           0.518084  -0.333293         -0.356934
# 8946 -0.742423           0.518084  -0.329136         -0.356934
# 8947 -0.740398          -0.185477  -0.401965         -0.356934
# 8948 -0.745174          -0.185477  -0.469552         -0.356934
# 8949 -0.572575          -0.889033   0.042146          0.301732
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                  -0.349079     -0.466786            -0.806490
# 1                  -0.454576      2.605605            -1.221758
# 2                  -0.454576     -0.466786             1.269843
# 3                  -0.454576     -0.368653            -1.014125
# 4                  -0.454576     -0.466786            -1.014125
# ...                      ...           ...                  ...
# 8945               -0.132643     -0.466786             1.269843
# 8946               -0.122823     -0.466786             1.269843
# 8947               -0.294893     -0.466786             0.854576
# 8948               -0.454576     -0.449352            -1.221758
# 8949               -0.454576     -0.406205             0.439310
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                      -0.678661                         -0.707313
# 1                      -0.678661                         -0.916995
# 2                       2.673451                         -0.916995
# 3                      -0.399319                         -0.916995
# 4                      -0.399319                         -0.916995
# ...                          ...                               ...
# 8945                   -0.678661                          1.179833
# 8946                   -0.678661                          1.179833
# 8947                   -0.678661                          0.760469
# 8948                   -0.678661                         -0.916995
# 8949                    1.556082                         -0.916995
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                  -0.675349         -0.476070      -0.511333     -0.960433
# 1                   0.573963          0.110074      -0.591796      0.688639
# 2                  -0.675349         -0.476070      -0.109020      0.826062
# 3                  -0.258913         -0.329534      -0.551565      0.826062
# 4                  -0.675349         -0.476070      -0.551565     -0.905464
# ...                      ...               ...            ...           ...
# 8945               -0.675349         -0.476070      -0.350408     -0.960433
# 8946               -0.675349         -0.476070      -0.350408     -0.960433
# 8947               -0.675349         -0.476070      -0.390639     -0.960433
# 8948                0.157527         -0.182998      -0.591796     -1.097856
# 8949                0.990398         -0.182998       0.333524     -0.905464
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# 0    -0.528979     -3.109675e-01         -0.525551  0.360680
# 1     0.818642      8.931021e-02          0.234227  0.360680
# 2    -0.383805     -1.016632e-01         -0.525551  0.360680
# 3    -0.598688     -4.390474e-16         -0.525551  0.360680
# 4    -0.364368     -2.657913e-01         -0.525551  0.360680
# ...        ...               ...               ...       ...
# 8945 -0.486217     -3.498541e-01          1.183951 -4.122768
# 8946 -0.503396     -4.390474e-16         -0.525551 -4.122768
# 8947 -0.570615     -3.354655e-01          0.329200 -4.122768
# 8948 -0.580536     -3.469065e-01          0.329200 -4.122768
# 8949 -0.576869     -3.329464e-01         -0.525551 -4.122768
#
# [8950 rows x 17 columns]

# %%
# plt.figure(figsize=(12,8))
# x = ss_cc_data["BALANCE"]
# y = ss_cc_data["PURCHASES"]
# snss = sns.scatterplot(x, y, hue = ss_cc_data["KMeans Segment"])
# plt.show
plt.figure(figsize=(12,8))
sns.kdeplot(data=km_data, x="BALANCE", y="PURCHASES", hue="KMeans Segment")
# Out:
# <AxesSubplot:xlabel='BALANCE', ylabel='PURCHASES'>

# %%
corr_cc_data = credit_card_data.corr()

fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr_cc_data, annot=True, cmap="Blues", fmt='.1g', linewidths=.5, ax = ax)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=km_data["BALANCE"], y=km_data["PURCHASES"], hue=km_data["KMeans Segment"])
# Out:
# <AxesSubplot:xlabel='BALANCE', ylabel='PURCHASES'>

# %%
sns.kdeplot(data=km_data, x=km_data["PURCHASES_FREQUENCY"], hue=km_data["KMeans Segment"])
# Out:
# <AxesSubplot:xlabel='PURCHASES_FREQUENCY', ylabel='Density'>

# %%
sns.kdeplot(data=km_data, x=km_data["PURCHASES_INSTALLMENTS"], hue=km_data["KMeans Segment"])

# %%
sns.kdeplot(data=km_data, x=km_data["PURCHASES_FREQUENCY"], hue=km_data["KMeans Segment"])
